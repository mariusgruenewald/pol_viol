# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install numpy

#import packages
import pandas as pd
import numpy as np
import datetime as dt
# Out:
# Requirement already satisfied: pandas in c:\users\mariu\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mariu\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mariu\anaconda3\lib\site-packages (from pandas) (1.20.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mariu\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\mariu\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: numpy in c:\users\mariu\anaconda3\lib\site-packages (1.20.2)

# %%
# Import data
data_crime = pd.read_csv(r'https://raw.githubusercontent.com/mariusgruenewald/pol_viol/main/crime_data_edited.csv')
data_share = pd.read_csv(r'https://raw.githubusercontent.com/mariusgruenewald/pol_viol/main/election_data_edited.csv')

# %%
# get into datetime format
data_crime['year'] = data_crime['date'].astype(str).str.split('.', expand=True)[2]
data_crime['month'] = data_crime['date'].astype(str).str.split('.', expand=True)[1]
data_crime['day'] = data_crime['date'].astype(str).str.split('.', expand=True)[0]
data_crime['date'] = pd.to_datetime(data_crime[['year', 'month', 'day']].astype(float), errors='ignore')

# %%
# Merge crime and candidate statistics with merge over city string
data_crime = data_crime[(data_crime['Land'] == 14) | (data_crime['Land'] == 8) | (data_crime['Land'] == 16) | (data_crime['Land'] == 12)]
data_share['city'] = data_share['city'].str.replace(r'Stadt ', '')
data_share['city'] = data_share['city'].str.replace('Ä', 'A').str.replace('Ö', 'O').str.replace('Ü', 'U')

list_cities_share = data_share.sort_values('city')['city'].unique()
list_cities_crime = data_crime['city'].unique()

data_crime.rename({'Land':'state'}, axis=1, inplace=True)
data_crime['state'] = data_crime['state'].map({16:'TH', 8:'BW', 14:'SN', 12:'BB'})
# Out:
# C:\Users\mariu\Anaconda3\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
data_share.rename({'year':'cycle_1'}, axis=1, inplace=True)
data_share['cycle_2'] = data_share['cycle_1']
data_share['cycle_3'] = data_share['cycle_1']

# %% [markdown]
# Merging over years and cities? How many different cutoffs? Directly on election day, one month before and three months before
#
# Cut-off days for the three states: 05.26.2019, 04.26.2019, 02.26.2019

# %%
# creating different cycle variables in crime data to merge over
#
data_crime['cycle_1'] = 2014
data_crime.loc[data_crime['date'] > dt.datetime(2019, 5, 26, 0, 0), 'cycle_1'] = 2019

data_crime['cycle_2'] = 2014
data_crime.loc[data_crime['date'] > dt.datetime(2019, 4, 26, 0, 0), 'cycle_2'] = 2019

data_crime['cycle_3'] = 2014
data_crime.loc[data_crime['date'] > dt.datetime(2019, 2, 26, 0, 0), 'cycle_3'] = 2019
# Out:
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\mariu\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# remove duplicates from data_share
# The following mistake happened: during merger full line and line w/out merger success being kept
# If done before, file will not contain unmatched entities -> necessary for manual inspection
#data_share.drop_duplicates(subset=['city','party','Anzahl Bewerber','darunter Frauen','cycle_1','state'], ignore_index=True, inplace=True)

# %%
# Find double cities in data share
# we cannot use plz here, since crime data doesn't have any of that -> merger on plz doesnt work
# list_double = pd.DataFrame()
# for city in data_share['city'].unique():
    
#     data_city = data_share[data_share['city'] == city]
#     for party in data_city['party'].unique():
        
#         data_party = data_city[data_city['party'] == party]
#         for election in data_party['cycle_1'].unique():
            
#             data_election = data_party[data_party['cycle_1'] == election]
            
#             if len(data_election) > 1:
                
#                 # append to dataset of 
#                 list_double = list_double.append(data_election)

# %%
# drop cities that are not uniquely identifable by cityname
#list_double_cities = data_share[data_share.city.isin(list_double.city)]['city'].unique()
#list_to_drop_crime = data_crime[data_crime.city.isin(list_double.city)]
#data_crime = data_crime[~data_crime.city.isin(list_to_drop_crime.city)]

# %%
data_share.dropna(inplace=True)

# Generate crime_count variable for easier handling
data_crime['crime_count'] = 1
data_crime.drop('Unnamed: 0', axis=1, inplace=True)
data_crime.dropna(subset=['party'], inplace=True)
# Out:
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\mariu\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\mariu\Anaconda3\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_merged = pd.merge(data_crime, data_share, on=['plz', 'city', 'cycle_1', 'party', 'state', 'cycle_2', 'cycle_3', 'city_id', 'bl_kuerzel'], how='right', validate='m:1')
data_merged.drop(['Unnamed: 0'], axis=1, inplace=True)
data_merged['crime_count'] = data_merged['crime_count'].fillna(0)
data_merged
# Out:
#                                                    crime                city  \
# 0                                       Sachbeschadigung           Stuttgart
# 1      Verleumdung ohne Verleumdung ohne sexuelle Gru...           Stuttgart
# 2                                        Volksverhetzung           Stuttgart
# 3                                       Sachbeschadigung           Stuttgart
# 4                                       Sachbeschadigung           Stuttgart
# ...                                                  ...                 ...
# 17839                                                NaN  Neuhaus am Rennweg
# 17840                                                NaN           Sonneberg
# 17841                                                NaN          Rudolstadt
# 17842                                                NaN      Saalfeld/Saale
# 17843                                                NaN            Possneck
#
#             law       date background  suspects  party state      plz  \
# 0      STGB-303 2019-07-25      Links       0.0    AfD    BW  70173.0
# 1      STGB-187 2019-07-25      Links       0.0    AfD    BW  70173.0
# 2      STGB-130 2019-08-12     Rechts       1.0    AfD    BW  70173.0
# 3      STGB-303 2019-08-26      Links       0.0    AfD    BW  70173.0
# 4      STGB-303 2019-07-25      Links       0.0    AfD    BW  70173.0
# ...         ...        ...        ...       ...    ...   ...      ...
# 17839       NaN        NaT        NaN       NaN  GRÜNE    TH  98724.0
# 17840       NaN        NaT        NaN       NaN  GRÜNE    TH  96515.0
# 17841       NaN        NaT        NaN       NaN  GRÜNE    TH   7407.0
# 17842       NaN        NaT        NaN       NaN  GRÜNE    TH   7318.0
# 17843       NaN        NaT        NaN       NaN  GRÜNE    TH   7381.0
#
#           city_id  ...  year month  day cycle_1  cycle_2  cycle_3  \
# 0       8111000.0  ...  2019    07   25  2019.0   2019.0   2019.0
# 1       8111000.0  ...  2019    07   25  2019.0   2019.0   2019.0
# 2       8111000.0  ...  2019    08   12  2019.0   2019.0   2019.0
# 3       8111000.0  ...  2019    08   26  2019.0   2019.0   2019.0
# 4       8111000.0  ...  2019    07   25  2019.0   2019.0   2019.0
# ...           ...  ...   ...   ...  ...     ...      ...      ...
# 17839  16072013.0  ...   NaN   NaN  NaN  2014.0   2014.0   2014.0
# 17840  16072018.0  ...   NaN   NaN  NaN  2014.0   2014.0   2014.0
# 17841  16073076.0  ...   NaN   NaN  NaN  2014.0   2014.0   2014.0
# 17842  16073077.0  ...   NaN   NaN  NaN  2014.0   2014.0   2014.0
# 17843  16075085.0  ...   NaN   NaN  NaN  2014.0   2014.0   2014.0
#
#        crime_count  Anzahl Bewerber  darunter Frauen  Land
# 0              1.0             60.0             16.0   8.0
# 1              1.0             60.0             16.0   8.0
# 2              1.0             60.0             16.0   8.0
# 3              1.0             60.0             16.0   8.0
# 4              1.0             60.0             16.0   8.0
# ...            ...              ...              ...   ...
# 17839          0.0              1.0              1.0  16.0
# 17840          0.0              7.0              1.0  16.0
# 17841          0.0             10.0              4.0  16.0
# 17842          0.0             13.0              5.0  16.0
# 17843          0.0              4.0              1.0  16.0
#
# [17844 rows x 21 columns]

# %%
data_merged_2 = data_merged.groupby('city').count()
print(f"Total num of cities w/ crime & target: {len(data_crime['city'].unique())}, \n")
print(f"Total num of cities w/ election: {len(data_share['city'].unique())}, \n")
print(f"Total num of cities w/ crime & election: {len(data_merged_2[data_merged_2['crime'] != 0])}, \n")
print(f"Total num of crime in df: {len(data_merged[~data_merged['crime'].isna()])}")
# Out:
# Total num of cities w/ crime & target: 465,
#
# Total num of cities w/ election: 1857,
#
# Total num of cities w/ crime & election: 149,
#
# Total num of crime in df: 1564

# %% [markdown]
# ### Generate various measures of crime

# %%
# regular summarization across cities and parties
data_crime_base = data_crime.groupby(['city', 'background', 'party', 'cycle_1', 'state'], as_index=False).sum()
data_crime_party = data_crime.groupby(['city', 'party', 'cycle_1', 'state'], as_index=False).sum()
data_crime_lr = data_crime[(data_crime['background'] == 'Links') | (data_crime['background'] == 'Rechts') | (data_crime['background'].isna())] #drop unidentified crime for left-right analysis
data_crime_lr_merge= data_crime_lr.groupby(['city', 'background', 'cycle_1', 'state'], as_index=False).sum()
data_crime_city = data_crime.groupby(['city', 'cycle_1', 'state'], as_index=False).sum()
data_crime_base.rename({'crime_count':'crime_count_party_lr'}, axis=1, inplace=True)
data_crime_party.rename({'crime_count':'crime_count_party'}, axis=1, inplace=True)
data_crime_lr_merge.rename({'crime_count':'crime_count_lr'}, axis=1, inplace=True)
data_crime_city.rename({'crime_count':'crime_count_city'}, axis=1, inplace=True)

# %%
# putting all measures into on dataframe. CAUTION: Alsways do drop_duplicates and dropna if other than crime_count used
data_merged = pd.merge(data_merged, data_crime_base[['city', 'background', 'party', 'cycle_1', 'state', 'crime_count_party_lr']], on=['city', 'background', 'party', 'cycle_1', 'state'], how='left', validate='m:1')
data_merged = pd.merge(data_merged, data_crime_party[['city', 'party', 'cycle_1', 'state', 'crime_count_party']], on=['city', 'party', 'cycle_1', 'state'], how='left', validate='m:1')
data_merged = pd.merge(data_merged, data_crime_lr_merge[['city', 'background', 'cycle_1', 'state', 'crime_count_lr']], on=['city', 'background', 'cycle_1', 'state'], how='left', validate='m:1')
data_merged = pd.merge(data_merged, data_crime_city[['city', 'cycle_1', 'state', 'crime_count_city']], on=['city', 'cycle_1', 'state'], how='left', validate='m:1')

# %%
for col in ('crime_count_party_lr','crime_count_party','crime_count_lr','crime_count_city'):
    data_merged[col].fillna(0, inplace=True)
data_merged.tail(5)
# Out:
#       crime                city  law date background  suspects  party state  \
# 17839   NaN  Neuhaus am Rennweg  NaN  NaT        NaN       NaN  GRÜNE    TH
# 17840   NaN           Sonneberg  NaN  NaT        NaN       NaN  GRÜNE    TH
# 17841   NaN          Rudolstadt  NaN  NaT        NaN       NaN  GRÜNE    TH
# 17842   NaN      Saalfeld/Saale  NaN  NaT        NaN       NaN  GRÜNE    TH
# 17843   NaN            Possneck  NaN  NaT        NaN       NaN  GRÜNE    TH
#
#            plz     city_id  ... cycle_2 cycle_3 crime_count Anzahl Bewerber  \
# 17839  98724.0  16072013.0  ...  2014.0  2014.0         0.0             1.0
# 17840  96515.0  16072018.0  ...  2014.0  2014.0         0.0             7.0
# 17841   7407.0  16073076.0  ...  2014.0  2014.0         0.0            10.0
# 17842   7318.0  16073077.0  ...  2014.0  2014.0         0.0            13.0
# 17843   7381.0  16075085.0  ...  2014.0  2014.0         0.0             4.0
#
#        darunter Frauen  Land  crime_count_party_lr  crime_count_party  \
# 17839              1.0  16.0                   0.0                0.0
# 17840              1.0  16.0                   0.0                0.0
# 17841              4.0  16.0                   0.0                0.0
# 17842              5.0  16.0                   0.0                0.0
# 17843              1.0  16.0                   0.0                0.0
#
#        crime_count_lr  crime_count_city
# 17839             0.0               0.0
# 17840             0.0               0.0
# 17841             0.0               5.0
# 17842             0.0               0.0
# 17843             0.0               3.0
#
# [5 rows x 25 columns]

# %%
data_share['party'].unique()
# Out:
# array(['AfD', 'CDU', 'DIE LINKE', 'FDP', 'GRÜNE', 'SPD'], dtype=object)

# %%
data_merged['party_lr'] = 'right'
data_merged.loc[(data_merged['party'] == 'SPD') | (data_merged['party'] == 'GRÜNE') | (data_merged['party'] == 'DIE LINKE'), 'party_lr'] = 'left'

# %% [markdown]
# ### Generate aggregation of fem_share

# %%
data_elec_by_crime_background = data_merged.groupby(['background', 'city', 'cycle_1', 'state', 'plz'], as_index=False).sum()[['background', 'city', 'cycle_1', 'state', 'plz', 'Anzahl Bewerber', 'darunter Frauen']]
city_crime = data_merged.groupby(['city', 'cycle_1', 'state', 'plz'], as_index=False).sum()[['city', 'cycle_1', 'state', 'plz', 'Anzahl Bewerber', 'darunter Frauen']]
data_elec_by_crime_background.rename({'Anzahl Bewerber':'bewerber_hit_by_lr', 'darunter Frauen':'fem_hit_by_lr'}, axis=1, inplace=True)
city_crime.rename({'Anzahl Bewerber':'Bewerber_city', 'darunter Frauen':'Frauen_city'}, axis=1, inplace=True)

# %%
data_merged = pd.merge(data_merged, city_crime, on=['city', 'cycle_1', 'state', 'plz'], how='left', validate='m:1')
data_merged = pd.merge(data_merged, data_elec_by_crime_background, on=['background', 'city', 'cycle_1', 'state', 'plz'], how='left', validate='m:1')

# %%
for col in ('bewerber_hit_by_lr','fem_hit_by_lr','Bewerber_city','Frauen_city'):
    data_merged[col].fillna(0, inplace=True)
data_merged
# Out:
#                                                    crime                city  \
# 0                                       Sachbeschadigung           Stuttgart
# 1      Verleumdung ohne Verleumdung ohne sexuelle Gru...           Stuttgart
# 2                                        Volksverhetzung           Stuttgart
# 3                                       Sachbeschadigung           Stuttgart
# 4                                       Sachbeschadigung           Stuttgart
# ...                                                  ...                 ...
# 17839                                                NaN  Neuhaus am Rennweg
# 17840                                                NaN           Sonneberg
# 17841                                                NaN          Rudolstadt
# 17842                                                NaN      Saalfeld/Saale
# 17843                                                NaN            Possneck
#
#             law       date background  suspects  party state      plz  \
# 0      STGB-303 2019-07-25      Links       0.0    AfD    BW  70173.0
# 1      STGB-187 2019-07-25      Links       0.0    AfD    BW  70173.0
# 2      STGB-130 2019-08-12     Rechts       1.0    AfD    BW  70173.0
# 3      STGB-303 2019-08-26      Links       0.0    AfD    BW  70173.0
# 4      STGB-303 2019-07-25      Links       0.0    AfD    BW  70173.0
# ...         ...        ...        ...       ...    ...   ...      ...
# 17839       NaN        NaT        NaN       NaN  GRÜNE    TH  98724.0
# 17840       NaN        NaT        NaN       NaN  GRÜNE    TH  96515.0
# 17841       NaN        NaT        NaN       NaN  GRÜNE    TH   7407.0
# 17842       NaN        NaT        NaN       NaN  GRÜNE    TH   7318.0
# 17843       NaN        NaT        NaN       NaN  GRÜNE    TH   7381.0
#
#           city_id  ...  Land crime_count_party_lr crime_count_party  \
# 0       8111000.0  ...   8.0                  6.0               8.0
# 1       8111000.0  ...   8.0                  6.0               8.0
# 2       8111000.0  ...   8.0                  2.0               8.0
# 3       8111000.0  ...   8.0                  6.0               8.0
# 4       8111000.0  ...   8.0                  6.0               8.0
# ...           ...  ...   ...                  ...               ...
# 17839  16072013.0  ...  16.0                  0.0               0.0
# 17840  16072018.0  ...  16.0                  0.0               0.0
# 17841  16073076.0  ...  16.0                  0.0               0.0
# 17842  16073077.0  ...  16.0                  0.0               0.0
# 17843  16075085.0  ...  16.0                  0.0               0.0
#
#       crime_count_lr  crime_count_city  party_lr  bewerber_hit_by_lr  \
# 0               10.0              16.0     right               600.0
# 1               10.0              16.0     right               600.0
# 2                6.0              16.0     right               240.0
# 3               10.0              16.0     right               600.0
# 4               10.0              16.0     right               600.0
# ...              ...               ...       ...                 ...
# 17839            0.0               0.0      left                 0.0
# 17840            0.0               0.0      left                 0.0
# 17841            0.0               5.0      left                 0.0
# 17842            0.0               0.0      left                 0.0
# 17843            0.0               3.0      left                 0.0
#
#        fem_hit_by_lr  Bewerber_city  Frauen_city
# 0              216.0         1020.0        375.0
# 1              216.0         1020.0        375.0
# 2               82.0         1020.0        375.0
# 3              216.0         1020.0        375.0
# 4              216.0         1020.0        375.0
# ...              ...            ...          ...
# 17839            0.0           41.0          9.0
# 17840            0.0           80.0         23.0
# 17841            0.0           68.0         16.0
# 17842            0.0           91.0         27.0
# 17843            0.0           34.0          7.0
#
# [17844 rows x 30 columns]

# %%
# p_female works with crime_count_party_lr and crime_count_party
data_merged['p_female'] = data_merged['darunter Frauen']/data_merged['Anzahl Bewerber']
data_merged['p_female_lr'] = data_merged['fem_hit_by_lr']/data_merged['bewerber_hit_by_lr']
data_merged['p_female_city'] = data_merged['Frauen_city']/data_merged['Bewerber_city']

# %%
data_merged.columns
# Out:
# Index(['crime', 'city', 'law', 'date', 'background', 'suspects', 'party',
#        'state', 'plz', 'city_id', 'bl_kuerzel', 'year', 'month', 'day',
#        'cycle_1', 'cycle_2', 'cycle_3', 'crime_count', 'Anzahl Bewerber',
#        'darunter Frauen', 'Land', 'crime_count_party_lr', 'crime_count_party',
#        'crime_count_lr', 'crime_count_city', 'party_lr', 'bewerber_hit_by_lr',
#        'fem_hit_by_lr', 'Bewerber_city', 'Frauen_city', 'p_female',
#        'p_female_city', 'p_female_lr'],
#       dtype='object')

# %% [markdown]
# ### What we have now:
# * Panel data set in levels -> always drop duplicates depending on level of analysis
#
# #### Later on, insert control variables here
#
# ### What we need:
# * Difference in election shares (caution still holds)

# %%
# Generate differences
data_panel_diff = data_merged[data_merged['cycle_1'] == 2014]
data_panel_diff
# Out:
#                   crime                city       law       date background  \
# 17          Beleidigung           Stuttgart  185 StGB 2019-01-09      Links
# 18     Sachbeschadigung           Stuttgart  303 StGB 2019-02-16      Links
# 19                  NaN           Stuttgart       NaN        NaT        NaN
# 20                  NaN           Stuttgart       NaN        NaT        NaN
# 21                  NaN           Stuttgart       NaN        NaT        NaN
# ...                 ...                 ...       ...        ...        ...
# 17839               NaN  Neuhaus am Rennweg       NaN        NaT        NaN
# 17840               NaN           Sonneberg       NaN        NaT        NaN
# 17841               NaN          Rudolstadt       NaN        NaT        NaN
# 17842               NaN      Saalfeld/Saale       NaN        NaT        NaN
# 17843               NaN            Possneck       NaN        NaT        NaN
#
#        suspects      party state      plz     city_id  ... crime_count_lr  \
# 17          1.0        AfD    BW  70173.0   8111000.0  ...           13.0
# 18          0.0        AfD    BW  70173.0   8111000.0  ...           13.0
# 19          NaN        CDU    BW  70173.0   8111000.0  ...            0.0
# 20          NaN  DIE LINKE    BW  70173.0   8111000.0  ...            0.0
# 21          NaN        FDP    BW  70173.0   8111000.0  ...            0.0
# ...         ...        ...   ...      ...         ...  ...            ...
# 17839       NaN      GRÜNE    TH  98724.0  16072013.0  ...            0.0
# 17840       NaN      GRÜNE    TH  96515.0  16072018.0  ...            0.0
# 17841       NaN      GRÜNE    TH   7407.0  16073076.0  ...            0.0
# 17842       NaN      GRÜNE    TH   7318.0  16073077.0  ...            0.0
# 17843       NaN      GRÜNE    TH   7381.0  16075085.0  ...            0.0
#
#       crime_count_city party_lr bewerber_hit_by_lr  fem_hit_by_lr  \
# 17                27.0    right              120.0           24.0
# 18                27.0    right              120.0           24.0
# 19                27.0    right                0.0            0.0
# 20                27.0     left                0.0            0.0
# 21                27.0    right                0.0            0.0
# ...                ...      ...                ...            ...
# 17839              0.0     left                0.0            0.0
# 17840              0.0     left                0.0            0.0
# 17841              5.0     left                0.0            0.0
# 17842              0.0     left                0.0            0.0
# 17843              3.0     left                0.0            0.0
#
#        Bewerber_city  Frauen_city  p_female  p_female_city  p_female_lr
# 17             420.0        159.0  0.200000            0.2     0.378571
# 18             420.0        159.0  0.200000            0.2     0.378571
# 19             420.0        159.0  0.466667            NaN     0.378571
# 20             420.0        159.0  0.466667            NaN     0.378571
# 21             420.0        159.0  0.316667            NaN     0.378571
# ...              ...          ...       ...            ...          ...
# 17839           41.0          9.0  1.000000            NaN     0.219512
# 17840           80.0         23.0  0.142857            NaN     0.287500
# 17841           68.0         16.0  0.400000            NaN     0.235294
# 17842           91.0         27.0  0.384615            NaN     0.296703
# 17843           34.0          7.0  0.250000            NaN     0.205882
#
# [8055 rows x 33 columns]

# %%
# drop units with only one observation
data_unique = data_merged.drop_duplicates(subset=['city', 'state', 'cycle_1', 'party', 'p_female'])
data_panel = pd.DataFrame()
for city in data_unique['city'].unique():
    data_city = data_unique[data_unique['city'] == city]
    
    for party in data_city['party'].unique():
        data_party = data_city[data_city['party'] == party]
        
        if len(data_party) > 1:
            
            diff = data_party[(data_party['cycle_1'] == 2019)]['p_female'].values - data_party[(data_party['cycle_1'] == 2014)]['p_female'].values
            data_merged.loc[(data_merged['party'] == party) & (data_merged['city'] == city), 'p_female_diff'] = diff[0]

# %%
test = data_merged.drop_duplicates(subset=['city', 'state', 'cycle_1', 'p_female_city'])
test[(test['city'] == 'Stuttgart')]
# Out:
#                crime       city       law       date background  suspects  \
# 0   Sachbeschadigung  Stuttgart  STGB-303 2019-07-25      Links       0.0
# 17       Beleidigung  Stuttgart  185 StGB 2019-01-09      Links       1.0
#
#    party state      plz    city_id  ... crime_count_city party_lr  \
# 0    AfD    BW  70173.0  8111000.0  ...             16.0    right
# 17   AfD    BW  70173.0  8111000.0  ...             27.0    right
#
#    bewerber_hit_by_lr fem_hit_by_lr  Bewerber_city  Frauen_city  p_female  \
# 0               600.0         216.0         1020.0        375.0  0.266667
# 17              120.0          24.0          420.0        159.0  0.200000
#
#     p_female_city  p_female_lr  p_female_diff
# 0        0.367647         0.36       0.066667
# 17       0.378571         0.20       0.066667
#
# [2 rows x 34 columns]

# %%
data_unique = data_merged.drop_duplicates(subset=['city', 'state', 'cycle_1', 'p_female_city'])
data_panel = pd.DataFrame()
for city in data_unique['city'].unique():
    data_city = data_unique[data_unique['city'] == city]
    
    if len(data_city) > 1:         
        diff = data_city[(data_city['cycle_1'] == 2019)]['p_female_city'].values - data_city[(data_city['cycle_1'] == 2014)]['p_female_city'].values
        data_merged.loc[(data_merged['city'] == city), 'p_female_city_diff'] = diff[0]

# %%
data_merged.head(40)[['p_female_lr', 'party', 'city', 'cycle_1', 'background']]
# Out:
#     p_female_lr      party       city  cycle_1 background
# 0      0.360000        AfD  Stuttgart   2019.0      Links
# 1      0.360000        AfD  Stuttgart   2019.0      Links
# 2      0.341667        AfD  Stuttgart   2019.0     Rechts
# 3      0.360000        AfD  Stuttgart   2019.0      Links
# 4      0.360000        AfD  Stuttgart   2019.0      Links
# 5      0.360000        AfD  Stuttgart   2019.0      Links
# 6      0.341667        AfD  Stuttgart   2019.0     Rechts
# 7      0.360000        AfD  Stuttgart   2019.0      Links
# 8      0.341667        CDU  Stuttgart   2019.0     Rechts
# 9      0.341667        CDU  Stuttgart   2019.0     Rechts
# 10          NaN  DIE LINKE  Stuttgart   2019.0        NaN
# 11          NaN        FDP  Stuttgart   2019.0        NaN
# 12     0.360000      GRÜNE  Stuttgart   2019.0      Links
# 13     0.360000      GRÜNE  Stuttgart   2019.0      Links
# 14     0.360000      GRÜNE  Stuttgart   2019.0      Links
# 15     0.360000      GRÜNE  Stuttgart   2019.0      Links
# 16          NaN        SPD  Stuttgart   2019.0        NaN
# 17     0.200000        AfD  Stuttgart   2014.0      Links
# 18     0.200000        AfD  Stuttgart   2014.0      Links
# 19          NaN        CDU  Stuttgart   2014.0        NaN
# 20          NaN  DIE LINKE  Stuttgart   2014.0        NaN
# 21          NaN        FDP  Stuttgart   2014.0        NaN
# 22          NaN      GRÜNE  Stuttgart   2014.0        NaN
# 23          NaN        SPD  Stuttgart   2014.0        NaN
# 24          NaN        AfD  Aidlingen   2019.0        NaN
# 25          NaN        CDU  Aidlingen   2019.0        NaN
# 26          NaN  DIE LINKE  Aidlingen   2019.0        NaN
# 27          NaN        FDP  Aidlingen   2019.0        NaN
# 28          NaN      GRÜNE  Aidlingen   2019.0        NaN
# 29          NaN        SPD  Aidlingen   2019.0        NaN
# 30          NaN        AfD  Aidlingen   2014.0        NaN
# 31          NaN        CDU  Aidlingen   2014.0        NaN
# 32          NaN  DIE LINKE  Aidlingen   2014.0        NaN
# 33          NaN        FDP  Aidlingen   2014.0        NaN
# 34          NaN      GRÜNE  Aidlingen   2014.0        NaN
# 35          NaN        SPD  Aidlingen   2014.0        NaN
# 36          NaN        AfD    Altdorf   2019.0        NaN
# 37          NaN        CDU    Altdorf   2019.0        NaN
# 38          NaN  DIE LINKE    Altdorf   2019.0        NaN
# 39          NaN        FDP    Altdorf   2019.0        NaN

# %%
data_merged

# %%
data_panel_diff['crime_count'] = data_panel_diff['crime_count'].fillna(0)
data_panel_diff.to_csv(r'C:\Users\mariu\Documents\pol_viol\pol_viol\data_election_crime_merged.csv')
# Out:
# C:\Users\mariu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
